# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Nina Edvardsdal** <br>
# **Consultant**

# %% [markdown]
# *I am interested in data science because you can do so many different and useful things with it.*

# %% [markdown]
# ### My code will print a sentence as well as doing som calculations

# %%
print("Hello. Here are some calculations: ")
2+3
# Out:
# Hello. Here are some calculations:
# 5

# %% [markdown]
# | column1 | column2 | column3 |
# | ------ | ------ | ------ |
# | cell | cell | cell
# |cell | cell | cell
# | cell | cell | cell
# | cell | cell | cell

# %% [markdown]
#  - This is a bulleted list
#  - with multiple
#  - bullets.

# %% [markdown]
# 1. This is
# 2. a numbered
# 3. list

# %% [markdown]
# ![360_F_97589769_t45CqXyzjz0KXwoBZT9PRaWGHRk5hQqQ.jpg](attachment:3ed91ae5-3272-4056-974f-1a890b588b2d.jpg)
